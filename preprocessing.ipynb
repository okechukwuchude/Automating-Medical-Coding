# %% [markdown]
# <a href="https://colab.research.google.com/github/okechukwuchude/Automating-Medical-Coding/blob/main/Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import stanza
import csv
import pandas as pd

# Build an English pipeline
stanza.download('en', package='mimic', processors={'ner': 'i2b2'}) # download English model
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'}) # initialize English neural pipeline

# %%
# Global variable to store all extracted texts
extracted_texts = []

# Global variable to store cumulative sentence count
global_sentence_count = 0

# %%
# Inside the function process_text_with_stanza, update the global_sentence_count
def process_text_with_stanza(text):
    global global_sentence_count
    doc = nlp(text)
    global_sentence_count += len(doc.sentences)  # Increment global_sentence_count by the number of sentences in the current document
    return doc

# %%
def extract_info_from_json(json_file_path, hadm_id_set):
    global extracted_texts
    global global_sentence_count  # Access the global global_sentence_count variable
    last_sentence_id = global_sentence_count  # Initialize last assigned sentence ID to global_sentence_count

    # Open the JSON file
    with open(json_file_path, 'r') as file:
        # Load JSON data from the file
        data = json.load(file)

        # Extract 'hadm_id' and 'comment' from the JSON data
        hadm_id = data.get('hadm_id', None)
        comment = data.get('comment', None)

        # If 'hadm_id' is not found, print a warning message
        if hadm_id is None:
            print(f"Warning: 'hadm_id' not found in {json_file_path}")
            return None

        # Add 'hadm_id' to the set
        hadm_id_set.add(hadm_id)

        # Extract 'notes' from the JSON data
        notes = data.get('notes', [])

        # Iterate through each note
        for note in notes:
            note_info = {}  # Initialize a dictionary to store note information

            # Add 'hadm_id' to the note information
            note_info['hadm_id'] = hadm_id

            # Extract information from the note
            note_info['note_id'] = note.get('note_id', None)
            note_info['category'] = note.get('category', None)
            note_info['description'] = note.get('description', None)

            # Extract annotations from the note
            annotations = note.get('annotations', [])
            annotations_info = []  # Initialize a list to store annotation information

            # Iterate through each annotation in the note
            for annotation in annotations:
                annotation_info = {}  # Initialize a dictionary to store annotation information

                # Extract information from the annotation
                annotation_info['begin'] = annotation.get('begin', None)
                annotation_info['end'] = annotation.get('end', None)
                annotation_info['code'] = annotation.get('code', None)
                annotation_info['code_system'] = annotation.get('code_system', None)
                annotation_info['description'] = annotation.get('description', None)
                annotation_info['type'] = annotation.get('type', None)
                annotation_info['covered_text'] = annotation.get('covered_text', None)

                annotations_info.append(annotation_info)  # Append annotation information to the list

            note_info['annotations'] = annotations_info  # Add annotations information to the note
            note_info['text'] = note.get('text', None)

            # Process text with Stanza
            if note_info['text']:
                processed_text = process_text_with_stanza(note_info['text'])
                note_info['processed_text'] = processed_text

                # Extract sentence information and generate labels
                sentence_info = []
                for sent in processed_text.sentences:
                    tokens = [word.text for word in sent.words]
                    labels = ['O'] * len(tokens)  # Initialize labels as 'O'

                    for annotation in note_info['annotations']:
                        begin = annotation['begin']
                        end = annotation['end']

                        word_indices = find_word_indices(sent.words, begin, end)

                        # Assign labels
                        if word_indices:
                            start_idx, end_idx = word_indices[0], word_indices[-1]
                            labels[start_idx] = 'B'
                            for idx in range(start_idx + 1, end_idx + 1):
                                labels[idx] = 'I'

                    # Assign a unique sentence ID
                    sentence_id = last_sentence_id + sent.index  # Calculate sentence ID based on last assigned ID and current sentence index

                    # Print the result for each sentence
                    print('Sentence ID:', sentence_id)
                    print('Sentence:', ' '.join(tokens))
                    print('Labels:', ' '.join(labels))
                    print()

                    sentence_info.append({
                        'sentence_id': sentence_id,
                        'words': tokens,
                        'labels': labels
                    })

                note_info['sentence_info'] = sentence_info
                last_sentence_id += len(processed_text.sentences)  # Update last_sentence_id

            extracted_texts.append(note_info)  # Append note information to the global variable

# %%
def find_word_indices(words, begin, end):
    # Create an empty list to store the indices of words found within the given range
    word_indices = []

    # Iterate through each token in the list of tokens
    for idx, word in enumerate(words):
        # Check if the start character of the token matches the beginning of the range
        # or if the token spans the beginning of the range
        if word.start_char == begin or (word.start_char < begin and word.end_char > begin):
            # If it matches, add the index of the token to the list of word indices
            word_indices.append(idx)
        # Check if the end character of the token matches the end of the range
        # or if the token spans the end of the range
        if word.end_char == end or (word.start_char < end and word.end_char > end):
            # If it matches, add the index of the token to the list of word indices
            word_indices.append(idx)
            break

    # Return the list of word indices found within the given range
    return word_indices

# %%
def generate_labels(words, annotations, start_token_idx, end_token_idx):
    labels = ['O'] * len(words)

    for annotation in annotations:
        code = annotation['code']

        # # Update labels for the matched words
        # if start_token_idx is not None and end_token_idx is not None:
        #     labels[start_token_idx] = f'B-{code}'
        #     for idx in range(start_token_idx + 1, end_token_idx + 1):
        #         labels[idx] = f'I-{code}'

    return labels

# %%
# Function to search for JSON files in a given folder and its subfolders
def search_files(folder_path):
    # Set to store unique hadm_id values
    hadm_id_set = set()

    # Recursively search for JSON files in the folder and its subfolders
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            if filename.endswith('.json'):
                # Construct the full path to the JSON file
                json_file_path = os.path.join(root, filename)
                print("Processing:", json_file_path)
                # Call extract_info_from_json function to extract information from the JSON file
                extract_info_from_json(json_file_path, hadm_id_set)
                # Print a separator after processing each file
                print("=" * 50)

    # Print the count of unique hadm_id values
    print("Total unique hadm_id count:", len(hadm_id_set))

# %%
# Specify the path to the main folder containing subfolders with JSON files
main_folder_path = r'C:\Users\okechukwu chude\Documents\NLP\text extraction\Automating-Medical-Coding\2'

# Call the search_files function to start searching for JSON files in the main folder and its subfolders
search_files(main_folder_path)
# Out:
# Processing: C:\Users\okechukwu chude\Documents\NLP\text extraction\Automating-Medical-Coding\2\100197-ICD-9.json
# Sentence ID: 0
# Sentence: Admission Date : [ **2136-10-23 **] Discharge Date : [ **2136-10-24 **]
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 1
# Sentence: Date of Birth : [ ** 2056-7-14 **] Sex : M
# Labels: O O O O O O O O O O O
#
# Sentence ID: 2
# Sentence: Service : NEUROSURGERY
# Labels: O O O
#
# Sentence ID: 3
# Sentence: Allergies : No Known Allergies / Adverse Drug Reactions
# Labels: O O O O O O O O O
#
# Sentence ID: 4
# Sentence: Attending :[** First Name3 ( LF ) 1835 **] Chief Complaint : Found down
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 5
# Sentence: Major Surgical or Invasive Procedure : None
# Labels: O O O O O O O
#
# Sentence ID: 6
# Sentence: History of Present Illness : 80M p/w a large R IPH with intraventricular extension , midline shift , and hydrocephalus .
# Labels: O O O O O O O O O O B O B I O O O O O B O
#
# Sentence ID: 7
# Sentence: The patient was found lying face up in his bathtub after having shaved .
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 8
# Sentence: There was no water in the tub and the shower was not turned on .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 9
# Sentence: He was found by a neighbor .
# Labels: O O O O O O O
#
# Sentence ID: 10
# Sentence: [** Name ( NI ) ** ] EMS , he was moaning and there was " tone in his left arm " which may have been consistent with posturing .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 11
# Sentence: He was taken to [ ** Hospital1 18 ** ] [ ** Location ( un ) 620 ** ] and head CT was performed , revealing a large intraparenchymal hemorrhage extending from the lower midbrain into the hypothalamus , thalamus and basal ganglia on the right , with significant mass effect , intraventricular extension with casting of the right ventricle and some blood product in the posterior [ ** Doctor Last Name 534 ** ] of the left lateral ventricle .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O B I O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 12
# Sentence: [ ** Hospital1 18 **] Neurosurgery was called and on review of imaging and reported exam - Mannitol 100gm and Decadron 10mg x1 was recommended and given .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 13
# Sentence: He was transferred to [ ** Hospital1 18 ** ] for a Neurosurgical evaluation .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 14
# Sentence: Dr [ ** Last Name ( STitle ) ** ] discussed and offered surgical intervention , but this was refused based on the family 's knowledge of his wishes to not prolong life if incapacitated .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 15
# Sentence: He also had signed a DNR / DNI order .
# Labels: O O O O O B O O O O
#
# Sentence ID: 16
# Sentence: He was clear that he did not want to be dependent of disabled .
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 17
# Sentence: The family asked to maintain his intubation while other family members arrive from inside and outside [ ** State 350 ** ] .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 18
# Sentence: They offered that he is an organ donor .
# Labels: O O O O O O O O O
#
# Sentence ID: 19
# Sentence: Past Medical
# Labels: O O
#
# Sentence ID: 20
# Sentence: History : - DIABETES TYPE II - HYPERLIPIDEMIA - GLAUCOMA - OSTEOARTHRITIS - CAROTID STENOSIS left 60 - 69 %, rt 50 - VASOVAGAL SYNCOPE - BACK PAIN
# Labels: O O O B I I O B O B O B O B I I I I I I I I O O O O O O
#
# Sentence ID: 21
# Sentence: Family History : NC
# Labels: O O O O
#
# Sentence ID: 22
# Sentence: Physical Exam :
# Labels: O O O
#
# Sentence ID: 23
# Sentence: No eye opening , pupils 2 mm and minimally react .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 24
# Sentence: No corneal on left , minimal corneal on right .
# Labels: O O O O O O O O O O
#
# Sentence ID: 25
# Sentence: Extensor posture with LUE , RUE attempts to localize , BLE withdraw to noxious stim .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 26
# Sentence: No gag , not overbreathing the vent .
# Labels: O O O O O O O O
#
# Sentence ID: 27
# Sentence: Tone increased in left arm , normal bulk .
# Labels: O O O O O O O O O
#
# Sentence ID: 28
# Sentence: Toes are downgoing bilaterally .
# Labels: O O O O O
#
# Sentence ID: 29
# Sentence: Pertinent Results : FINDINGS :
# Labels: O O O O O
#
# Sentence ID: 30
# Sentence: There is a large intraparenchymal basal ganglionic based hemorrhage .
# Labels: O O O O O O O O O O
#
# Sentence ID: 31
# Sentence: It is multilobulated in nature and at its greatest extent measures 6.5 x 5.3 cm .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 32
# Sentence: This is causing mass effect and shift of the normally midline structures of approximately 1.1 cm at the level of the hemorrhage .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 33
# Sentence: There is also intraventricular extension into the ipsilateral and contralateral lateral ventricles .
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 34
# Sentence: There is effacement of the ipsilateral frontal [ ** Doctor Last Name 534 **] of the lateral ventricle
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 35
# Sentence: Brief Hospital Course : Pt was admitted to the neurosurgery service and the ICU .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 36
# Sentence: The organ bank was contact [ ** Name ( NI ) ** ] .
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 37
# Sentence: [ ** Name2 ( NI ) ** ] was extubated on [ * * 10 - 24 ** ] without incident and a morphine drip was started and titrated to respiratory rate .
# Labels: O O O O O O O O O B O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 38
# Sentence: He passed away on [ ** 10 - 24 ** ] at 12:55 p.m.
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 39
# Sentence: The family declined a post morteum exam .
# Labels: O O O O O O O O
#
# Sentence ID: 40
# Sentence: Medications on Admission : None
# Labels: O O O O O
#
# Sentence ID: 41
# Sentence: Discharge Medications : None
# Labels: O O O O
#
# Sentence ID: 42
# Sentence: Discharge Disposition : Expired
# Labels: O O O O
#
# Sentence ID: 43
# Sentence: Discharge Diagnosis : Intracranial hemorrhage
# Labels: O O O O O
#
# Sentence ID: 44
# Sentence: Discharge Condition : Expired
# Labels: O O O O
#
# Sentence ID: 45
# Sentence: Discharge Instructions : None
# Labels: O O O O
#
# Sentence ID: 46
# Sentence: Followup Instructions : None
# Labels: O O O O
#
# Sentence ID: 47
# Sentence: Completed by :[**2136-10-24 **]
# Labels: O O O O
#
# ==================================================
# Processing: C:\Users\okechukwu chude\Documents\NLP\text extraction\Automating-Medical-Coding\2\ICD-10\1.0\101525-ICD-10.json
# Sentence ID: 48
# Sentence: Demographics Day of intubation : Day of mechanical ventilation : 2 Ideal body weight : 0 None Ideal tidal volume : 0 / 0 / 0 mL /kg Airway Airway Placement Data Known difficult intubation : Unknown Tube
# Labels: O O O O O B I I I I I O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 49
# Sentence: Type ETT : Position : 22 cm at teeth Route : Oral Type : Standard Size : 7 mm Lung sounds RLL Lung Sounds : Clear RUL Lung Sounds : Clear LUL Lung Sounds : Clear LLL Lung Sounds : Clear Comments : Secretions Sputum color / consistency : Blood Tinged / Thick Sputum source / amount : Suctioned / Small Comments : Ventilation Assessment Level of breathing assistance : Continuous invasive ventilation Visual assessment of breathing pattern : Normal quiet breathing ; Comments : Remain on vent support .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 50
# Sentence: Will attempt PSV after AM Head CT.
# Labels: O O O O O O O
#
# Sentence ID: 51
# Sentence: Assessment of breathing comfort : No response ( sleeping / sedated )
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 52
# Sentence: Invasive ventilation assessment : Trigger work assessment : Triggering synchronously Dysynchrony assessment : Frequent alarms ( High min . ventilation ) Comments : Plan Next 24 - 48 hours :
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 53
# Sentence: Continue with daily RSBI tests & SBT 's as tolerated ; Comments :
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 54
# Sentence: Will attempt RSBI once on PSV ^ settled aftyer returning [ ** Last Name ( un ) 5215 **]
# Labels: O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 55
# Sentence: Head CT.
# Labels: O O
#
# Sentence ID: 56
# Sentence: Reason for continuing current ventilatory support : Sedated / Paralyzed , Hemodynimic instability , Underlying illness not resolved
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 57
# Sentence: [ ** 2134-3-22 **] 4:49 AM CT HEAD W/O CONTRAST Clip # [ ** Clip Number ( Radiology ) 73648 **] Reason : Perform ~5AM - evaluated for interval change ( known open sku Admitting Diagnosis : S/P MVC ______________________________________________________________________________
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 58
# Sentence: [ ** Hospital 2 **]
# Labels: O O O O O
#
# Sentence ID: 59
# Sentence: MEDICAL CONDITION : 24 year old woman s/p MVC REASON FOR THIS EXAMINATION :
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 60
# Sentence: Perform ~5AM - evaluated for interval change ( known open skull fx ) No contraindications for IV contrast ______________________________________________________________________________
# Labels: O O O O O O O O O B I I O O O O O O O
#
# Sentence ID: 61
# Sentence: FINAL REPORT
# Labels: O O
#
# Sentence ID: 62
# Sentence: ( REVISED ) INDICATION : 24 -year-old woman , status post MVC .
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 63
# Sentence: Evaluate for open skull fracture .
# Labels: O O O B I O
#
# Sentence ID: 64
# Sentence: COMPARISON : None available .
# Labels: O O O O O
#
# Sentence ID: 65
# Sentence: TECHNIQUE : Non-contrast head CT.
# Labels: O O O O O
#
# Sentence ID: 66
# Sentence: Multiplanar reformations were generated .
# Labels: O O O O O
#
# Sentence ID: 67
# Sentence: FINDINGS :
# Labels: O O
#
# Sentence ID: 68
# Sentence: There is a left frontal epidural hematoma measuring 1.6 x 4.8 cm .
# Labels: O O O O O B I O O O O O O
#
# Sentence ID: 69
# Sentence: There is also associated small amount of left subdural / epidural blood , which measures 2.4 mm ( 2:19 ) .
# Labels: O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 70
# Sentence: There are no intraparenchymal foci of hemorrhage .
# Labels: O O O O O O O O
#
# Sentence ID: 71
# Sentence: There is moderate gyral effacement due to the epidural hematoma .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 72
# Sentence: There is no significant shift of midline structures .
# Labels: O O O O O O O O O
#
# Sentence ID: 73
# Sentence: The ventricles and sulci are normal in size and configuration .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 74
# Sentence: The [ ** Known lastname 107 ** ] and white matter differentiation is well preserved .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 75
# Sentence: There is no evidence of downward transtentorial or subfalcine herniation .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 76
# Sentence: Small amount of pneumocephalus is noted in the left frontal region .
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 77
# Sentence: IMPRESSION :
# Labels: O O
#
# Sentence ID: 78
# Sentence: There is a left frontal epidural hematoma and a small associated subdural / epidural hematoma as described above .
# Labels: O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 79
# Sentence: The above findings were communicated verbally to the neurosurgical resident on - call , Dr. [ ** First Name8 ( NamePattern2 ) 3922 **] [ ** Last Name ( NamePattern1 ) 1368 ** ] at 5:55 a.m. on [ ** 2134-3-22 ** ] .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 80
# Sentence: Final Attending Comment :
# Labels: O O O O
#
# Sentence ID: 81
# Sentence: There is a fracture of the left frontal bone and on image 36 , a tiny bony fragment appears to have been displaced into the brain .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 82
# Sentence: Admission Date : [ **2134-3-21 ** ] Discharge Date : [ ** 2134-3-26 **]
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 83
# Sentence: Date of Birth : [ ** 2109-8-19 **] Sex : F
# Labels: O O O O O O O O O O O
#
# Sentence ID: 84
# Sentence: Service : SURGERY
# Labels: O O O
#
# Sentence ID: 85
# Sentence: Allergies : Patient recorded as having No Known Allergies to Drugs
# Labels: O O O O O O O O O O O
#
# Sentence ID: 86
# Sentence: Attending :[** First Name3 ( LF ) 4691 **] Chief Complaint : s/p Motor vehicle crash
# Labels: O O O O O O O O O O O O O B I I
#
# Sentence ID: 87
# Sentence: Major Surgical or Invasive Procedure : [ ** 2134-3-21 **]
# Labels: O O O O O O O O O O
#
# Sentence ID: 88
# Sentence: Closure of scalp laceration Washout & closure of left arm laceration
# Labels: O O O O O O O O O O O
#
# Sentence ID: 89
# Sentence: History of Present Illness : 24 year old female who was an unrestrained driver in a motor vehicle crash .
# Labels: O O O O O O O O O O O O B I I I I I I O
#
# Sentence ID: 90
# Sentence: The vehicle reportedly rotated 360 and was hit twice .
# Labels: O O O O O O O O O O
#
# Sentence ID: 91
# Sentence: The patient was partially ejected from the vehicle and sustained a open skull fracture as well as evulsed left arm .
# Labels: O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 92
# Sentence: She was intubated at the scene with a BP 80/50 and brought to [ ** Hospital6 23267 ** ] where she received blood and normal saline .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 93
# Sentence: She was then transferred to [ ** Hospital1 18 ** ] ED.
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 94
# Sentence: Upon initial presentation she was moving all extremities .
# Labels: O O O O O O O O O
#
# Sentence ID: 95
# Sentence: Past Medical History : None
# Labels: O O O O O
#
# Sentence ID: 96
# Sentence: Family History : Noncontributory
# Labels: O O O O
#
# Sentence ID: 97
# Sentence: Physical Exam : Upon admission : Vital Signs :T : 96.8 BP : 121/83 HR:105 R:20 O2Sats :100 Gen : intubated non-responsive HEENT : Pupils : left 2.5 mm fixed , right pupil 2.5 minimally responsive EOMs fixed Extrem : left arm evulsion fracture , finger with poor circulation pale blue color Neuro : Mental status : intubated , non responsive Orientation : non responsive Recall / Language : none Cranial Nerves : I : Not tested II : Pupils equal left 2.5 mm fixed , right pupil 2.5 minimally responsive III , IV , VI : Extraocular movements - eyes fixed V , VII , VIII , IX , X , [ ** Doctor First Name 81 ** ] , XII , Motor / Sensation /coordination : unable to test pt with [ ** Location ( un ) 2611 **] scale 3
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 98
# Sentence: Corneal : absent
# Labels: O O O
#
# Sentence ID: 99
# Sentence: Gag : present
# Labels: O O O
#
# Sentence ID: 100
# Sentence: Toes downgoing bilaterally
# Labels: O O O
#
# Sentence ID: 101
# Sentence: Pertinent Results : [ ** 2134-3-21 ** ] 09:19 PM TYPE -[** Last Name ( un ) ** ] PO2-73 * PCO2-42 PH-7.25 * TOTAL CO2-19 * BASE XS--8 COMMENTS-QUESTION S [ ** 2134-3-21 ** ] 09:19 PM GLUCOSE-179 * LACTATE-4.7 * NA +-137 K+-3.1 * CL --107 [ ** 2134-3-21 ** ] 09:19 PM HGB -11.9 * calcHCT-36 [ ** 2134-3-21 ** ] 07:40PM ASA-NEG ETHANOL-NEG ACETMNPHN-NEG bnzodzpn-NEG barbitrt-NEG tricyclic-NEG [ ** 2134-3-21 ** ] 07:40 PM WBC -11.0 RBC-3.78 * HGB -11.7 * HCT -33.3 * MCV-88 MCH -30.9 MCHC -35.0 RDW - 13.3 [ ** 2134-3-21 ** ] 07:40 PM PLT COUNT -230 [ ** 2134-3-21 ** ] 07:40 PM PT - 14.3 * PTT -30.2 INR ( PT ) - 1.2 * [ ** 2134-3-21 ** ] 07:40 PM FIBRINOGE-114*
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 102
# Sentence: CT Head [ ** 2134-3-22 **]
# Labels: O O O O O O
#
# Sentence ID: 103
# Sentence: IMPRESSION :
# Labels: O O
#
# Sentence ID: 104
# Sentence: There is a left frontal epidural hematoma and a small associated subdural / epidural hematoma as described above .
# Labels: O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 105
# Sentence: Final Attending Comment :
# Labels: O O O O
#
# Sentence ID: 106
# Sentence: There is a fracture of the left frontal bone and on image 36 , a tiny bony fragment appears to have been displaced into the brain .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 107
# Sentence: Repeat head CT [ ** 2134-3-23 **]
# Labels: O O O O O O O
#
# Sentence ID: 108
# Sentence: IMPRESSION :
# Labels: O O
#
# Sentence ID: 109
# Sentence: Unchanged left frontal hematoma with overlying frontoparietal skull fracture and scalp hematoma .
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 110
# Sentence: Unchanged smaller more inferior extra-axial left frontal hematoma .
# Labels: O O O O O O O O O
#
# Sentence ID: 111
# Sentence: CT cervical spine [ ** 2134-3-23 **]
# Labels: O O O O O O O
#
# Sentence ID: 112
# Sentence: IMPRESSION :
# Labels: O O
#
# Sentence ID: 113
# Sentence: 1 . No fracture or subluxation .
# Labels: O O O O O O O
#
# Sentence ID: 114
# Sentence: 2 . Extensive soft tissue stranding / hemorrhage in the left supraclavicular region which may relate to recent attempt at central venous access ( no clavicular fracture is seen ) ; correlate clinically .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 115
# Sentence: Brief Hospital Course : She was admitted to the Trauma service and taken to the operating room emergently for incision debridement repair of biceps and soft tissue defect left upper arm irrigation and debridement closure of open skull fracture with 12 cm scalp laceration .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 116
# Sentence: Postoperatively she was taken to the Trauma ICU where she remained sedated and intubated for several days .
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 117
# Sentence: She was eventually extubated without any difficulty .
# Labels: O O O O O O O O
#
# Sentence ID: 118
# Sentence: Neurosurgery was consulted for the epidural / subdural frontal hemorrhage .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 119
# Sentence: She was placed on Dilantin which will continue for a 7 day course as prophylaxis for seizures .
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 120
# Sentence: Repeat head CT scans remained stable .
# Labels: O O O O O O O
#
# Sentence ID: 121
# Sentence: Neurologically she is alert and oriented x2 for the most part ; some difficulty intermittently with remembering where she is .
# Labels: O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 122
# Sentence: She has been able to follow commands and answer simple questions appropriately .
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 123
# Sentence: She was eventually transferred to the regular nursing unit .
# Labels: O O O O O O O O O O
#
# Sentence ID: 124
# Sentence: She was evaluated by Plastics for her left metacarpal fracture ; this was managed nonoperative with a ulnar splint and she will follow up in [ ** Hospital 3595 ** ] clinic in about a week after discharge .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 125
# Sentence: Orthopedics was consulted for her left clavicle fracture , this was also managed nonoperative with a sling .
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 126
# Sentence: She is to remain non weight bearing on her left arm and will follow up in 2 weeks in orthopedics clinic .
# Labels: O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 127
# Sentence: On HD # 5 she was noted to complain of blurred vision with intermittent diplopia ; an Ophthalmology consult was placed and it was felt that she had a traumatic 6th nerve palsy and no operative intervention was warranted .
# Labels: O O O O O O O O O O B I O B I O O O O O O O O O O O O O O O B I I O O O O O O O
#
# Sentence ID: 128
# Sentence: Physical and Occupational therapy were consulted and have recommended acute rehab after her hospital stay .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 129
# Sentence: The screening process was initiated and discharge plans were underway .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 130
# Sentence: Social work was consulted for coping and emotional support .
# Labels: O O O O O O O O O O
#
# Sentence ID: 131
# Sentence: Medications on Admission : OCP's
# Labels: O O O O O
#
# Sentence ID: 132
# Sentence: Discharge Medications : 1 . Phenytoin Sodium Extended 100 mg Capsule Sig : One ( 1 ) Capsule PO TID ( 3 times a day ) for 5 days .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 133
# Sentence: 2 . Famotidine 20 mg Tablet Sig : One ( 1 ) Tablet PO BID ( 2 times a day ) .
# Labels: O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 134
# Sentence: 3 . Ferrous Sulfate 325 mg ( 65 mg Iron ) Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 135
# Sentence: 4 . Folic Acid 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 136
# Sentence: ( Daily ) .
# Labels: O O O O
#
# Sentence ID: 137
# Sentence: 5 . Docusate Sodium 100 mg Capsule Sig : One ( 1 ) Capsule PO BID ( 2 times a day ) .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 138
# Sentence: 6 . Morphine 15 mg Tablet Sustained Release Sig : One ( 1 ) Tablet Sustained Release PO Q12H ( every 12 hours ) .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 139
# Sentence: 7 . Morphine 15 mg Tablet Sig : 1-2 Tablets PO Q3H
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 140
# Sentence: ( every 3 hours ) as needed for breakthrough pain .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 141
# Sentence: 8 . Senna 8.6 mg Tablet Sig : Two ( 2 ) Tablet PO HS ( at bedtime ) .
# Labels: O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 142
# Sentence: 9 . Magnesium Hydroxide 400 mg/5 mL Suspension Sig : Thirty ( 30 ) ML PO Q6H
# Labels: O O O O O O O O O O O O O O O O O
#
# Sentence ID: 143
# Sentence: ( every 6 hours ) as needed for constipation .
# Labels: O O O O O O O O O O
#
# Sentence ID: 144
# Sentence: 10 . Bisacodyl 10 mg Suppository Sig : One ( 1 ) Suppository Rectal HS ( at bedtime ) as needed for constipation .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 145
# Sentence: Discharge Disposition : Extended Care
# Labels: O O O O O
#
# Sentence ID: 146
# Sentence: Facility : [ ** Hospital6 85 **] - [ ** Location ( un ) 86 **]
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 147
# Sentence: Discharge Diagnosis : s/p Motor vehicle crash Scalp laceration Epidural Hematoma Skull Fracture Left clavicle fracture Left metacarpal fracture Left arm laceration Traumatic 6th nerve palsy
# Labels: O O O O B I I O O B I B I B I I B I I B I I B I I I
#
# Sentence ID: 148
# Sentence: Discharge Condition : Hemodynamically stable , tolerating a regular diet , pain adequately controlled .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 149
# Sentence: Discharge Instructions : Continue Dilantin until [ ** 2134-3-30 **]
# Labels: O O O O O O O O O O
#
# Sentence ID: 150
# Sentence: Followup Instructions : Follow up with Dr. [ ** First Name ( STitle ) ** ] , Neurosurgery in [ ** 9 - 29 ** ] days .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 151
# Sentence: Call [ ** Telephone / Fax ( 1 ) 1669 ** ] for an appointment .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 152
# Sentence: Inform the office that a repeat non contrast head CT is needed for this appointment .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 153
# Sentence: Follow up in Plastics / Hand clinic next Tuesday [ ** 3 -30 ** ] , call [ ** Telephone / Fax ( 1 ) 3009 ** ] for an appointment .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 154
# Sentence: Follow up next Tuesday [ ** 3-30 ** ] with Dr. [ ** Last Name ( STitle ) ** ] , Trauma Surgery for removal of your scalp and left arm staples .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 155
# Sentence: Call [ ** Telephone / Fax ( 1 ) 6429 ** ] for an appoitnment .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 156
# Sentence: Follow up in 2 weeks with Dr. [ ** Last Name ( STitle ) 1005 ** ] , Orthopedics for your clavicle fracture , call [ ** Telephone / Fax ( 1 ) 1228 ** ] for an appointment .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 157
# Sentence: Follow up in [ ** Hospital ** ] clinic in 2 weeks , call [ ** Telephone / Fax ( 1 ) 253 ** ] for an appointnment .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 158
# Sentence: Completed by :[**2134-6-9 **]
# Labels: O O O O
#
# Sentence ID: 159
# Sentence: SICU HPI : 24 yo F unrestrained driver in roll-over MVC .
# Labels: O O O O O O B I I I I O
#
# Sentence ID: 160
# Sentence: Partial ejection from car .
# Labels: O O O O O
#
# Sentence ID: 161
# Sentence: GCS at scene unknown , but responsive only to pain - intubated at scene .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 162
# Sentence: Non-depressed skull fracture with overlying laceration , and L arm laceration to bone .
# Labels: B I I O O O O O B I I O O O
#
# Sentence ID: 163
# Sentence: At OSH recieved ancef , tetnus and 2 pRBC .
# Labels: O O O O O O O O O O
#
# Sentence ID: 164
# Sentence: Chief complaint : PMHx : none Current medications : 24 Hour Events :
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 165
# Sentence: EXTUBATION - At [ ** 2134-3-22 **] 10:56 AM INVASIVE VENTILATION - STOP [ ** 2134-3-22 **] 10:56 AM intubated in field MULTI LUMEN - STOP [ ** 2134-3-22 **] 04:02 PM EKG - At [ ** 2134-3-23 **] 01:06 AM peaked T waves noted on EKG , 12 lead EKG obtained Allergies : No Known Drug Allergies Last dose of Antibiotics : Cefazolin - [ **2134-3-22 **] 09:57 AM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 166
# Sentence: Infusions : Other ICU medications : Midazolam ( Versed ) - [ ** 2134-3-22 **] 05:30 AM Propofol - [ ** 2134-3-22 **] 05:56 AM Fentanyl - [ ** 2134-3-22 **] 08:01 AM Dilantin - [ ** 2134-3-22 **] 08:09 AM Famotidine ( Pepcid ) - [**2134-3-22 **] 08:11 AM Hydromorphone ( Dilaudid ) - [**2134-3-23 **] 12:40 AM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 167
# Sentence: Other medications : Flowsheet Data as of [ **2134-3-23 ** ] 05:16 AM
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 168
# Sentence: Vital signs Hemodynamic monitoring Fluid balance 24 hours Since [ ** 36 **] a.m. Tmax : 38.1 C ( 100.5 T current : 37.7 C ( 99.8 HR : 88 ( 86 - 119 ) bpm BP : 109/55(66 ) {89/49(60 ) - 117/71(82 ) } mmHg RR : 21 ( 11 - 28 ) insp / min SPO2 : 100 % Heart rhythm : SR ( Sinus Rhythm ) Wgt ( current ) : 55 kg ( admission ) : 55 kg Total In : 2,165 mL 30 mL PO : 140 mL 30 mL
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 169
# Sentence: Tube feeding : IV Fluid : 2,025 mL
# Labels: O O O O O O O O
#
# Sentence ID: 170
# Sentence: Blood products : Total out : 1,550 mL 1,300 mL Urine : 1,450 mL 1,300 mL NG : 100 mL
# Labels: O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 171
# Sentence: Stool : Drains : Balance : 615 mL - 1,270 mL Respiratory support O2 Delivery Device : Nasal cannula Ventilator mode : CPAP / PSV
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 172
# Sentence: Vt ( Set ) : 450 ( 450 - 450 ) mL Vt ( Spontaneous ) : 480 ( 480 - 528 ) mL PS : 8 cmH2O RR ( Set ) : 16 RR ( Spontaneous ) : 7 PEEP : 5 cmH2O FiO2 : 30 % RSBI : 44 PIP : 13 cmH2O Plateau : 12 cmH2O SPO2 : 100 % ABG : ///23 / Ve : 5.7 L/min Physical Examination General Appearance : No acute distress Cardiovascular : ( Rhythm : Regular )
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 173
# Sentence: Respiratory / Chest : ( Breath Sounds :
# Labels: O O O O O O O O
#
# Sentence ID: 174
# Sentence: CTA bilateral : )
# Labels: O O O O
#
# Sentence ID: 175
# Sentence: Abdominal : Soft , Non-distended , Non-tender Left Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) , ( Pulse - Posterior tibial : Present ) Right Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) , ( Pulse - Posterior tibial : Present ) Neurologic : ( Awake / Alert / Oriented : x 3 ) , Follows simple commands , ( Responds to : Verbal stimuli ) , Moves all extremities Labs / Radiology 174 K/uL 8.8 g/dL 121 mg/dL 0.6 mg /dL 23 mEq /L 3.5 mEq /L 5 mg /dL 108 mEq/L 139 mEq/L 24.5 % 8.6 K/uL [ image002.jpg ] [ ** 2134-3-21 **] 09:19 PM [ ** 2134-3-22 **] 12:02 AM [ ** 2134-3-22 **] 12:37 AM [ ** 2134-3-22 **] 04:34 AM [ ** 2134-3-23 **] 01:01 AM WBC 10.7 8.6 Hct 36 27.5 27 24.5 Plt 177 174 Creatinine 0.8 0.6 TCO2 21 Glucose 179 128 121
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 176
# Sentence: Other labs : PT / PTT / INR:14.7/30.9/1.3 , Lactic Acid:3.8 mmol / L , Ca:9.1 mg /dL , Mg :1.9 mg /dL , PO4:3.1 mg/dL Assessment and Plan NEURO : Repeat CT shows stable epidural .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 177
# Sentence: Q1 Hr neuro checks .
# Labels: O O O O O
#
# Sentence ID: 178
# Sentence: Dilaudid , percocet , tylenol for pain .
# Labels: O O O O O O O O
#
# Sentence ID: 179
# Sentence: repeat head CT in AM CVS : SBP < 140 , prn hydral PULM : extubated GI : NPO , H2 blocker
# Labels: O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 180
# Sentence: RENAL :
# Labels: O O
#
# Sentence ID: 181
# Sentence: Cr stable , continue to follow .
# Labels: O O O O O O O
#
# Sentence ID: 182
# Sentence: Is acidotic with elevated lactate .
# Labels: O O O O O O
#
# Sentence ID: 183
# Sentence: continue to follow HEME : HCT stable , continue to follow ENDO : RISS ID : cefzolin MuskSkel : plastics splinted left wrist , f/u with them in clinic next Tue , sling on left shoulder for clavicle fx TLD : foley , LSC triple IJ , piv , aline IVF : None CONSULTS : Trauma , NSGY BILLING DIAGNOSIS : skull fracture ICU CARE : GLYCEMIC CONTROL : RISS PROPHYLAXIS : DVT - Boots ,
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B I O O O O O O O O O O O O O
#
# Sentence ID: 184
# Sentence: SQH STRESS ULCER - H2B VAP BUNDLE - Yes COMMUNICATIONS : Parents ICU Consent : Signed CODE STATUS : Full
# Labels: O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 185
# Sentence: DISPOSITION : transfer to Stepdown Lines : 20 Gauge - [**2134-3-22 **] 05:00 PM
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 186
# Sentence: Total time spent : 35 min
# Labels: O O O O O O
#
# Sentence ID: 187
# Sentence: TSICU HPI : 24 yo F unrestrained driver in roll-over MVC .
# Labels: O O O O O O B I I I I O
#
# Sentence ID: 188
# Sentence: Partial ejection from car .
# Labels: O O O O O
#
# Sentence ID: 189
# Sentence: GCS at scene unknown , but responsive only to pain - intubated at scene .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 190
# Sentence: Non-depressed skull fracture with overlying laceration , and L arm laceration to bone .
# Labels: O B I O O O O O B I I O O O
#
# Sentence ID: 191
# Sentence: At OSH recieved ancef , tetnus and 2 pRBC .
# Labels: O O O O O O O O O O
#
# Sentence ID: 192
# Sentence: Chief complaint : Non-depressed skull fracture , multiple lacerations , and with epidural hematoma PMHx : PMH : None PSH : None Current medications : 24 Hour Events : Post operative day : [ **3-24 **] POD
# Labels: O O O B I I O O O O O O B I O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 193
# Sentence: 3 Allergies : No Known Drug Allergies Last dose of Antibiotics : Cefazolin - [ **2134-3-22 **] 09:57 AM
# Labels: O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 194
# Sentence: Infusions : Other ICU medications : Famotidine ( Pepcid ) - [** 2134-3-23 **] 08:00 PM Hydromorphone ( Dilaudid ) - [**2134-3-24 **] 05:15 AM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 195
# Sentence: Other medications : Flowsheet Data as of [ **2134-3-24 ** ] 06:26 AM
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 196
# Sentence: Vital signs Hemodynamic monitoring Fluid balance 24 hours Since [ ** 36 **] a.m. Tmax : 37.7 C ( 99.8 T current : 37.2 C ( 98.9 HR : 80 ( 78 - 95 ) bpm BP : 109/65(77 ) {99/61(69 ) - 122/82(92 ) } mmHg RR : 17 ( 12 - 22 ) insp / min SPO2 : 100 % Heart rhythm : SR ( Sinus Rhythm ) Wgt ( current ) : 55.7 kg ( admission ) : 55 kg Total In : 980 mL 240 mL PO : 880 mL 240 mL
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 197
# Sentence: Tube feeding : IV Fluid : 100 mL
# Labels: O O O O O O O O
#
# Sentence ID: 198
# Sentence: Blood products : Total out : 2,299 mL 500 mL Urine : 2,299 mL 500 mL NG : Stool : Drains : Balance : - 1,319 mL - 260 mL Respiratory support O2 Delivery Device : Nasal cannula SPO2 : 100 % ABG : / //26 / Physical Examination General Appearance : No acute distress
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 199
# Sentence: HEENT : PERRL
# Labels: O O O
#
# Sentence ID: 200
# Sentence: Cardiovascular : ( Rhythm : Regular ) Respiratory / Chest : ( Expansion : Symmetric ) , ( Breath Sounds :
# Labels: O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 201
# Sentence: CTA bilateral : ) , ( Sternum : Stable ) Abdominal : Soft , Non-distended , Non-tender Left Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) Right Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) Neurologic : ( Awake / Alert / Oriented : x 3 ) , Follows simple commands , ( Responds to : Verbal stimuli , Tactile stimuli , Noxious stimuli ) , Moves all extremities , Alert to self .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 202
# Sentence: Incorrect location and date .
# Labels: O O O O O
#
# Sentence ID: 203
# Sentence: Unable to tell year of birthdate Labs / Radiology 204 K/uL 8.1 g/dL 122 mg /dL 0.5 mg /dL 26 mEq/L 3.7 mEq/L 7 mg /dL 103 mEq /L 138 mEq /L 23.0 % 7.4 K/uL [ image002.jpg ] [ ** 2134-3-21 **] 09:19 PM [ ** 2134-3-22 **] 12:02 AM [ ** 2134-3-22 **] 12:37 AM [ ** 2134-3-22 **] 04:34 AM [ ** 2134-3-23 **] 01:01 AM [ ** 2134-3-24 ** ] 02:00 AM WBC 10.7 8.6 7.4 Hct 36 27.5 27 24.5 23.0 Plt 177 174 204 Creatinine 0.8 0.6 0.5 TCO2 21 Glucose 179 128 121 122
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 204
# Sentence: Other labs : PT / PTT / INR:12.5/25.0/1.1 , Lactic Acid:3.8 mmol / L , Ca:8.4 mg /dL , Mg :2.0 mg /dL , PO4:2.7 mg/dL Assessment and Plan ACUTE PAIN , TRAUMA , S/P Assessment and Plan : 24 yo F in MVC suffering Non-depressed skull fracture , multiple lacerations , and with epidural hematoma Neurologic : MVC with non-depressed skull fx and epidural hematoma stable on CT head x2 , no intervention at this point .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B I I O O O O O O B I O O O O O O O O B I O O O O O O O O O O O O
#
# Sentence ID: 205
# Sentence: Neuro check q1hr. Mental status unchanged .
# Labels: O O O O O O O
#
# Sentence ID: 206
# Sentence: Dilaudid , percocet , tylenol for pain .
# Labels: O O O O O O O O
#
# Sentence ID: 207
# Sentence: C-spine pending clearance by trauma .
# Labels: O O O O O O
#
# Sentence ID: 208
# Sentence: CT neck ok , but still c/o neck pain .
# Labels: O O O O O O O O O O
#
# Sentence ID: 209
# Sentence: Trauma to adresst this am .
# Labels: O O O O O O
#
# Sentence ID: 210
# Sentence: Dilantin for sz proph Cardiovascular : SBP < 140 , prn hydral
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 211
# Sentence: Pulmonary : no resp issues ,
# Labels: O O O O O O
#
# Sentence ID: 212
# Sentence: Incentive spirometry Gastrointestinal / Abdomen : sips , H2 blocker Nutrition : tolerated clears , advance diet today Renal : Cr stable , UOP adequate Hematology : HCT steady decline 33 -->27-->24--> 23 , recheck this pm Endocrine : RISS Infectious Disease : monitor wbc , afebrile Lines / Tubes / Drains : foley , piv Wounds : c/d / i Imaging : none Fluids : KVO Consults : Neuro surgery , Trauma surgery Billing Diagnosis : Multiple Trauma ICU Care Nutrition : diet Glycemic Control : Regular insulin sliding scale Lines : 20 Gauge - [**2134-3-22 **] 05:00 PM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 213
# Sentence: Prophylaxis : DVT : Boots Stress ulcer : H2 blocker po VAP bundle : Comments : Communication : ICU consent signed Comments : Code status : Full code Disposition : ICU
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 214
# Sentence: Total time spent : 31 minutes
# Labels: O O O O O O
#
# Sentence ID: 215
# Sentence: [ ** 2134-3-22 **] 10:43 AM WRIST ( 3 + VIEWS ) BILAT Clip # [ ** Clip Number ( Radiology ) 73649 **] Reason : hand fx Admitting Diagnosis : S/P MVC ______________________________________________________________________________
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 216
# Sentence: [ ** Hospital 2 **]
# Labels: O O O O O
#
# Sentence ID: 217
# Sentence: MEDICAL CONDITION :
# Labels: O O O
#
# Sentence ID: 218
# Sentence: 24 year old woman s/p MVA with hand swelling REASON FOR THIS EXAMINATION :
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 219
# Sentence: hand fx , r/o foreign body ______________________________________________________________________________
# Labels: O O O O O O O
#
# Sentence ID: 220
# Sentence: FINAL REPORT
# Labels: O O
#
# Sentence ID: 221
# Sentence: THREE VIEWS , BOTH HANDS
# Labels: O O O O O
#
# Sentence ID: 222
# Sentence: INDICATION : Status post MVA .
# Labels: O O O O O O
#
# Sentence ID: 223
# Sentence: Hand swelling .
# Labels: O O O
#
# Sentence ID: 224
# Sentence: Assess for fracture or foreign body .
# Labels: O O O O O O O
#
# Sentence ID: 225
# Sentence: RIGHT HAND :
# Labels: O O O
#
# Sentence ID: 226
# Sentence: There is no evidence of acute fracture .
# Labels: O O O O O O O O
#
# Sentence ID: 227
# Sentence: No radiopaque foreign body is seen .
# Labels: O O O O O O O
#
# Sentence ID: 228
# Sentence: LEFT HAND :
# Labels: O O O
#
# Sentence ID: 229
# Sentence: There is a small fragment displaced from the dorsal aspect of the base of one of the left metacarpals .
# Labels: O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 230
# Sentence: It is seen only on the lateral view where the second through fourth _____ overlap each other .
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 231
# Sentence: It most likely arises from the dorsal aspect of the base of the third metacarpal .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 232
# Sentence: IMPRESSION :
# Labels: O O
#
# Sentence ID: 233
# Sentence: No evidence of radiopaque foreign body .
# Labels: O O O O O O O
#
# Sentence ID: 234
# Sentence: Small fracture fragment arising from the dorsal aspect of the base of one of the left metacarpals , most likely the third , although it is difficult to be certain since these metacarpals overlap on the lateral view which is the only view where the fracture is seen .
# Labels: O O O O O O O O O B I I I I I I I O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 235
# Sentence: Report phoned to Dr. [ ** First Name8 ( NamePattern2 ) 6311 **] [ ** Last Name ( NamePattern1 ) 7673 **] at 2:30 p.m. on 6 _____ [ ** 2133** ].
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 236
# Sentence: TSICU HPI : 24 yo F unrestrained driver in roll-over MVC .
# Labels: O O O O O O B I I I I O
#
# Sentence ID: 237
# Sentence: Partial ejection from car .
# Labels: O O O O O
#
# Sentence ID: 238
# Sentence: GCS at scene unknown , but responsive only to pain - intubated at scene .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 239
# Sentence: Non-depressed skull fracture with overlying laceration , and L arm laceration to bone .
# Labels: B I I O O O O O O O O O O O
#
# Sentence ID: 240
# Sentence: At OSH recieved ancef , tetnus and 2 pRBC .
# Labels: O O O O O O O O O O
#
# Sentence ID: 241
# Sentence: Chief complaint : Non-depressed skull fracture , multiple lacerations , and with epidural hematoma PMHx : PMH : None PSH : None Current medications : 24 Hour Events : Post operative day : [ **3-24 **] POD
# Labels: O O O B I I O O O O O O B I O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 242
# Sentence: 3 Allergies : No Known Drug Allergies Last dose of Antibiotics : Cefazolin - [ **2134-3-22 **] 09:57 AM
# Labels: O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 243
# Sentence: Infusions : Other ICU medications : Famotidine ( Pepcid ) - [** 2134-3-23 **] 08:00 PM Hydromorphone ( Dilaudid ) - [**2134-3-24 **] 05:15 AM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 244
# Sentence: Other medications : Flowsheet Data as of [ **2134-3-24 ** ] 06:26 AM
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 245
# Sentence: Vital signs Hemodynamic monitoring Fluid balance 24 hours Since [ ** 36 **] a.m. Tmax : 37.7 C ( 99.8 T current : 37.2 C ( 98.9 HR : 80 ( 78 - 95 ) bpm BP : 109/65(77 ) {99/61(69 ) - 122/82(92 ) } mmHg RR : 17 ( 12 - 22 ) insp / min SPO2 : 100 % Heart rhythm : SR ( Sinus Rhythm ) Wgt ( current ) : 55.7 kg ( admission ) : 55 kg Total In : 980 mL 240 mL PO : 880 mL 240 mL
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 246
# Sentence: Tube feeding : IV Fluid : 100 mL
# Labels: O O O O O O O O
#
# Sentence ID: 247
# Sentence: Blood products : Total out : 2,299 mL 500 mL Urine : 2,299 mL 500 mL NG : Stool : Drains : Balance : - 1,319 mL - 260 mL Respiratory support O2 Delivery Device : Nasal cannula SPO2 : 100 % ABG : / //26 / Physical Examination General Appearance : No acute distress
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 248
# Sentence: HEENT : PERRL
# Labels: O O O
#
# Sentence ID: 249
# Sentence: Cardiovascular : ( Rhythm : Regular ) Respiratory / Chest : ( Expansion : Symmetric ) , ( Breath Sounds :
# Labels: O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 250
# Sentence: CTA bilateral : ) , ( Sternum : Stable ) Abdominal : Soft , Non-distended , Non-tender Left Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) Right Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) Neurologic : ( Awake / Alert / Oriented : x 1 ) , Follows simple commands , ( Responds to : Verbal stimuli , Tactile stimuli , Noxious stimuli ) , Moves all extremities , Alert to self .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 251
# Sentence: Incorrect location and date .
# Labels: O O O O O
#
# Sentence ID: 252
# Sentence: Unable to tell year of birthdate Labs / Radiology 204 K/uL 8.1 g/dL 122 mg /dL 0.5 mg /dL 26 mEq/L 3.7 mEq/L 7 mg /dL 103 mEq /L 138 mEq /L 23.0 % 7.4 K/uL [ image002.jpg ] [ ** 2134-3-21 **] 09:19 PM [ ** 2134-3-22 **] 12:02 AM [ ** 2134-3-22 **] 12:37 AM [ ** 2134-3-22 **] 04:34 AM [ ** 2134-3-23 **] 01:01 AM [ ** 2134-3-24 ** ] 02:00 AM WBC 10.7 8.6 7.4 Hct 36 27.5 27 24.5 23.0 Plt 177 174 204 Creatinine 0.8 0.6 0.5 TCO2 21 Glucose 179 128 121 122
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 253
# Sentence: Other labs : PT / PTT / INR:12.5/25.0/1.1 , Lactic Acid:3.8 mmol / L , Ca:8.4 mg /dL , Mg :2.0 mg /dL , PO4:2.7 mg/dL Assessment and Plan ACUTE PAIN , TRAUMA , S/P Assessment and Plan : 24 yo F in MVC suffering Non-depressed skull fracture , multiple lacerations , and with epidural hematoma Neurologic : MVC with non-depressed skull fx and epidural hematoma stable on CT head x2 , no intervention at this point .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B I I O O O O O O B I O O O O O O O O B I O O O O O O O O O O O O
#
# Sentence ID: 254
# Sentence: Neuro check q1hr. Mental status unchanged .
# Labels: O O O O O O O
#
# Sentence ID: 255
# Sentence: Dilaudid , percocet , tylenol for pain .
# Labels: O O O O O O O O
#
# Sentence ID: 256
# Sentence: C-spine pending clearance by trauma .
# Labels: O O O O O O
#
# Sentence ID: 257
# Sentence: Dilantin for sz proph Cardiovascular : SBP < 140 , prn hydral Pulmonary : no resp issues Gastrointestinal / Abdomen : sips , H2 blocker Nutrition : Renal : Cr stable , UOP adequate Hematology : HCT steady decline 33-->27-->24-->23 Endocrine : RISS Infectious Disease : no active issues Lines / Tubes / Drains : foley , piv Wounds : Imaging : Fluids : KVO Consults : Neuro surgery , Trauma surgery Billing Diagnosis : ICU Care Nutrition : Glycemic Control : Regular insulin sliding scale Lines : 20 Gauge - [**2134-3-22 **] 05:00 PM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 258
# Sentence: Prophylaxis : DVT : Boots Stress ulcer : H2 blocker VAP bundle : Comments : Communication : ICU consent signed Comments : Code status : Full code Disposition : ICU
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 259
# Sentence: Total time spent : 23 minutes
# Labels: O O O O O O
#
# Sentence ID: 260
# Sentence: TSICU HPI : 24 yo F unrestrained driver in roll-over MVC .
# Labels: O O O O O O B I I I I O
#
# Sentence ID: 261
# Sentence: Partial ejection from car .
# Labels: O O O O O
#
# Sentence ID: 262
# Sentence: GCS at scene unknown , but responsive only to pain - intubated at scene .
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 263
# ...
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 391
# Sentence: Other labs : PT / PTT / INR:14.7/30.9/1.3 , Lactic Acid:3.8 mmol / L , Ca:9.1 mg /dL , Mg :1.9 mg /dL , PO4:3.1 mg/dL Assessment and Plan NEURO : Repeat CT shows stable epidural .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 392
# Sentence: Q1 Hr neuro checks .
# Labels: O O O O O
#
# Sentence ID: 393
# Sentence: Dilaudid , percocet for pain .
# Labels: O O O O O O
#
# Sentence ID: 394
# Sentence: repeat head CT in AM , c/o posterior neck pain today .
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 395
# Sentence: I do not see neck films from this hosp admission .
# Labels: O O O O O O O O O O O
#
# Sentence ID: 396
# Sentence: Will check with trauma re : OSH films .
# Labels: O O O O O O O O O
#
# Sentence ID: 397
# Sentence: Have optho see for left eye ecchymosis CVS : SBP < 140 , prn hydral PULM : extubated , monitor sats , IS GI : H2 blocker , advance diet RENAL : Cr stable , continue to follow UOP , adequate thus far .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 398
# Sentence: HEME : HCT stable , continue to follow ENDO : RISS ID : wbc improved , afebrile , ancef off MuskSkel : plastics splinted left wrist , f/u with them in clinic next Tue , sling on left shoulder for clavicle fx TLD : foley , piv IVF : KVO CONSULTS : Trauma , NSGY , ortho , plastics , ophtho
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 399
# Sentence: BILLING DIAGNOSIS : skull fracture ICU CARE : GLYCEMIC CONTROL : RISS PROPHYLAXIS : DVT - Boots
# Labels: O O O B I O O O O O O O O O O O O
#
# Sentence ID: 400
# Sentence: STRESS ULCER - H2B VAP BUNDLE - Yes COMMUNICATIONS : Parents ICU Consent : Signed CODE STATUS : Full
# Labels: O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 401
# Sentence: DISPOSITION : transfer to Stepdown Lines : 20 Gauge - [**2134-3-22 **] 05:00 PM
# Labels: O O B I I O O O O O O O O O
#
# Sentence ID: 402
# Sentence: Total time spent : 32 min
# Labels: O O O O O O
#
# Sentence ID: 403
# Sentence: TSICU HPI : 41yo M p/w severe HA , N/V. @OSH , CT showing SAH .
# Labels: O O O O O O O O O O O O O O B O
#
# Sentence ID: 404
# Sentence: Sent to [ ** Hospital1 1** ] , repeat CT showing high attenuation at bifurcation of basilar into posterior cerbral artery .
# Labels: O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 405
# Sentence: Neurologically intact .
# Labels: O O O
#
# Sentence ID: 406
# Sentence: Chief complaint : severe HA , n/v PMHx : PMH : glaucoma , kidney stone PSH : lithotripsy , right corneal transplant , multiple R eye [ ** Doctor First Name ** ]
# Labels: O O O O O O O O O O O B O O O O O O O B I I O O O O O O O O O O O
#
# Sentence ID: 407
# Sentence: Current medications : 24 Hour Events : Post operative day : [ **3-24 **] HD1
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 408
# Sentence: Allergies : No Known Drug Allergies Last dose of Antibiotics : Cefazolin - [ **2134-3-22 **] 09:57 AM
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 409
# Sentence: Infusions : Other ICU medications : Famotidine ( Pepcid ) - [** 2134-3-23 **] 08:00 PM Hydromorphone ( Dilaudid ) - [**2134-3-24 **] 05:15 AM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 410
# Sentence: Other medications : Flowsheet Data as of [ ** 2134-3-24 ** ] 06:36 AM
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 411
# Sentence: Vital signs Hemodynamic monitoring Fluid balance 24 hours Since [ ** 36 **] a.m. Tmax : 37.7 C ( 99.8 T current : 37.2 C ( 98.9 HR : 80 ( 78 - 95 ) bpm BP : 109/65(77 ) {99/61(69 ) - 122/82(92 ) } mmHg RR : 17 ( 12 - 22 ) insp / min SPO2 : 100 % Heart rhythm : SR ( Sinus Rhythm ) Wgt ( current ) : 55.7 kg ( admission ) : 55 kg Total In : 980 mL 240 mL PO : 880 mL 240 mL
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 412
# Sentence: Tube feeding : IV Fluid : 100 mL
# Labels: O O O O O O O O
#
# Sentence ID: 413
# Sentence: Blood products : Total out : 2,299 mL 500 mL Urine : 2,299 mL 500 mL NG : Stool : Drains : Balance : - 1,319 mL - 260 mL Respiratory support O2 Delivery Device : Nasal cannula SPO2 : 100 % ABG : / //26 / Physical Examination General Appearance : No acute distress HEENT : right eye surgical , left eye reactive Cardiovascular : ( Rhythm : Regular ) Respiratory / Chest : ( Expansion : Symmetric ) , ( Breath Sounds :
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 414
# Sentence: CTA bilateral : )
# Labels: O O O O
#
# Sentence ID: 415
# Sentence: Abdominal : Soft , Non-distended , Non-tender Left Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) Right Extremities : ( Edema : Absent ) , ( Temperature : Warm ) , ( Pulse - Dorsalis pedis : Present ) Neurologic : ( Awake / Alert / Oriented : x 3 ) , Follows simple commands , Moves all extremities Labs / Radiology 204 K/uL 8.1 g/dL 122 mg /dL 0.5 mg /dL 26 mEq /L 3.7 mEq / L 7 mg /dL 103 mEq /L 138 mEq /L 23.0 % 7.4 K/uL [ image002.jpg ] [ ** 2134-3-21 **] 09:19 PM [ ** 2134-3-22 **] 12:02 AM [ ** 2134-3-22 **] 12:37 AM [ ** 2134-3-22 **] 04:34 AM [ ** 2134-3-23 **] 01:01 AM [ ** 2134-3-24 ** ] 02:00 AM WBC 10.7 8.6 7.4 Hct 36 27.5 27 24.5 23.0 Plt 177 174 204 Creatinine 0.8 0.6 0.5 TCO2 21 Glucose 179 128 121 122
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 416
# Sentence: Other labs : PT / PTT / INR:12.5/25.0/1.1 , Lactic Acid:3.8 mmol / L , Ca:8.4 mg /dL , Mg :2.0 mg /dL , PO4:2.7 mg/dL Assessment and Plan ACUTE PAIN , TRAUMA , S/ P Assessment and Plan : 41yo M p/w SAH at ?
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B O O
#
# Sentence ID: 417
# Sentence: bifurcation of basilar into posterior cerbral artery Neurologic : SAH , unknown etiology .
# Labels: O O O O O O O O O B O O O O
#
# Sentence ID: 418
# Sentence: q1hr neuro checks .
# Labels: O O O O
#
# Sentence ID: 419
# Sentence: Nimodipine 60 mg PO Q4H for spasm proph. goal SBP < 140 ; Pain controlled with fent .
# Labels: O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 420
# Sentence: Dilantin for sz proph ; possible CTA to find source of bleed , possible angiogram ; h/o right eye glaucoma - to determine home eye gtts Cardiovascular : goal SBP < 140 .
# Labels: O O O O O O O O O O O O O O O O O O O B O O O O O O O O O O O O O
#
# Sentence ID: 421
# Sentence: Currently at goal w /o NiCARdipine .
# Labels: O O O O O O O
#
# Sentence ID: 422
# Sentence: Pulmonary : no active issues Gastrointestinal / Abdomen : NPO , H2B Nutrition : NPO
# Labels: O O O O O O O O O O O O O O O
#
# Sentence ID: 423
# Sentence: Renal : monitor UOP w/ foley
# Labels: O O O O O O
#
# Sentence ID: 424
# Sentence: Hematology : no active issues .
# Labels: O O O O O O
#
# Sentence ID: 425
# Sentence: Endocrine : RISS Infectious
# Labels: O O O O
#
# Sentence ID: 426
# Sentence: Disease : no active issue ; WBC elevated likely from acute event .
# Labels: O O O O O O B I O O O O O
#
# Sentence ID: 427
# Sentence: Lines / Tubes / Drains : A-line , PIV , foley Wounds : Imaging : Fluids : NS20K @ 80
# Labels: O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 428
# Sentence: Consults : Neuro surgery Billing Diagnosis : ( Hemorrhage , NOS : Sub-arachnoid ) ICU Care Nutrition : Glycemic Control : Regular insulin sliding scale Lines : 20 Gauge - [**2134-3-22 **] 05:00 PM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 429
# Sentence: Prophylaxis : DVT : Boots Stress ulcer : H2 blocker VAP bundle : Comments : Communication : ICU consent signed Comments : Code status : Full code Disposition : ICU
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 430
# Sentence: Total time spent : 23 minutes
# Labels: O O O O O O
#
# Sentence ID: 431
# Sentence: [ ** 2134-3-21 ** ] 8:16 PM HUMERUS ( AP & LAT ) LEFT ; HUMERUS ( AP & LAT ) LEFT Clip # [ ** Clip Number ( Radiology ) 73378 **] HAND ( AP , LAT & OBLIQUE ) LEFT Reason : Avulsion of LUE ______________________________________________________________________________
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 432
# Sentence: [ ** Hospital 2 **]
# Labels: O O O O O
#
# Sentence ID: 433
# Sentence: MEDICAL CONDITION :
# Labels: O O O
#
# Sentence ID: 434
# Sentence: 24 year old woman s/p MVC / ejection
# Labels: O O O O O O O O
#
# Sentence ID: 435
# Sentence: REASON FOR THIS EXAMINATION :
# Labels: O O O O O
#
# Sentence ID: 436
# Sentence: Avulsion of LUE ______________________________________________________________________________
# Labels: O O O O
#
# Sentence ID: 437
# Sentence: FINAL REPORT
# Labels: O O
#
# Sentence ID: 438
# Sentence: INDICATION : 24 -year-old female status post motor vehicle collision ejection .
# Labels: O O O O O O O O O O O O
#
# Sentence ID: 439
# Sentence: Evaluate left upper extremity .
# Labels: O O O O O
#
# Sentence ID: 440
# Sentence: Six views of the left upper extremity show fracture of the left clavicle .
# Labels: O O O O O O O O B I I I I O
#
# Sentence ID: 441
# Sentence: Ossific density projecting along the dorsum of the wrist on lateral projection likey relates to fracture of the dorsal base of the third or fourth metacarpal .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 442
# Sentence: Note is made of soft tissue swelling overlying this region of abnormality .
# Labels: O O O O O O O O O O O O O
#
# Sentence ID: 443
# Sentence: Correlate with exam .
# Labels: O O O O
#
# Sentence ID: 444
# Sentence: [ ** 2134-3-23 **] 6:05 PM CT C-SPINE W/O CONTRAST Clip # [ ** Clip Number ( Radiology ) 73778 **] Reason : cervical injury / instability Admitting Diagnosis : S/P MVC ______________________________________________________________________________
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 445
# Sentence: [ ** Hospital 2 **]
# Labels: O O O O O
#
# Sentence ID: 446
# Sentence: MEDICAL CONDITION : 24 year old woman s/p MVC .
# Labels: O O O O O O O O O O
#
# Sentence ID: 447
# Sentence: neck pain .
# Labels: B I O
#
# Sentence ID: 448
# Sentence: REASON FOR THIS EXAMINATION :
# Labels: O O O O O
#
# Sentence ID: 449
# Sentence: cervical injury / instability No contraindications for IV contrast ______________________________________________________________________________ PROVISIONAL FINDINGS IMPRESSION ( PFI ) : KYg TUE [ ** 2134-3-23 **] 7:18 PM
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 450
# Sentence: 1 . No fracture or subluxation .
# Labels: O O O O O O O
#
# Sentence ID: 451
# Sentence: 2 . Soft tissue stranding in the left supraclavicular region for which correlation with central venous access should be made .
# Labels: O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 452
# Sentence: ______________________________________________________________________________
# Labels: O
#
# Sentence ID: 453
# Sentence: FINAL REPORT
# Labels: O O
#
# Sentence ID: 454
# Sentence: INDICATION : 24 -year-old female status post motor vehicle collision with neck pain .
# Labels: O O O O O O O O O O O O O O
#
# Sentence ID: 455
# Sentence: Evaluate for cervical injury , instability .
# Labels: O O O O O O O
#
# Sentence ID: 456
# Sentence: COMPARISON : None .
# Labels: O O O O
#
# Sentence ID: 457
# Sentence: TECHNIQUE : Non-contrast MDCT - acquired axial images of the cervical spine from the skull base to the level of T2 .
# Labels: O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 458
# Sentence: Multiplanar reformatted images were obtained .
# Labels: O O O O O O
#
# Sentence ID: 459
# Sentence: FINDINGS :
# Labels: O O
#
# Sentence ID: 460
# Sentence: The alignment of the cervical spine , other than focal kyphosis at C5/6 , which may relate to positioning in a collar , with no [ ** First Name5 ( NamePattern1 ) ** ] [ ** Last Name ( NamePattern1 ) 73779 ** ] .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 461
# Sentence: There is no evidence of fracture .
# Labels: O O O O O O O
#
# Sentence ID: 462
# Sentence: The prevertebral soft tissues are normal .
# Labels: O O O O O O O
#
# Sentence ID: 463
# Sentence: The skull base is unremarkable .
# Labels: O O O O O O
#
# Sentence ID: 464
# Sentence: There is moderate mucosal thickening involving both sphenoid sinuses and their pterygoid recess , and opacification of a few scattered right mastoid air cells .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 465
# Sentence: The lung apices are clear .
# Labels: O O O O O O
#
# Sentence ID: 466
# Sentence: Soft tissue inflammatory change in the left supraclavicular region may relate to central venous access .
# Labels: O O O O O O O O O O O O O O O O
#
# Sentence ID: 467
# Sentence: IMPRESSION :
# Labels: O O
#
# Sentence ID: 468
# Sentence: 1 . No fracture or subluxation .
# Labels: O O O O O O O
#
# Sentence ID: 469
# Sentence: 2 . Extensive soft tissue stranding / hemorrhage in the left supraclavicular region which may relate to recent attempt at central venous access ( no clavicular fracture is seen ) ; correlate clinically .
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 470
# Sentence: [ ** Last Name ( LF ) ** ] , [** First Name3 ( LF ) 1046 **] J. [ ** Last Name ( un ) 1481 **]
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 471
# Sentence: TSICU [ ** 2134-3-23 **] 6:05 PM CT C-SPINE W/O CONTRAST Clip # [ ** Clip Number ( Radiology ) 73778 **] Reason : cervical injury / instability Admitting Diagnosis : S/P MVC ______________________________________________________________________________
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 472
# Sentence: [ ** Hospital 2 **]
# Labels: O O O O O
#
# Sentence ID: 473
# Sentence: MEDICAL CONDITION : 24 year old woman s/p MVC .
# Labels: O O O O O O O O O O
#
# Sentence ID: 474
# Sentence: neck pain .
# Labels: B I O
#
# Sentence ID: 475
# Sentence: REASON FOR THIS EXAMINATION :
# Labels: O O O O O
#
# Sentence ID: 476
# Sentence: cervical injury / instability No contraindications for IV contrast ______________________________________________________________________________ PFI REPORT 1 . No fracture or subluxation .
# Labels: O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 477
# Sentence: 2 . Soft tissue stranding in the left supraclavicular region for which correlation with central venous access should be made .
# Labels: O O O O O O O O O O O O O O O O O O O O O
#
# Sentence ID: 478
# Sentence: Sinus rhythm .
# Labels: B I O
#
# Sentence ID: 479
# Sentence: Diffuse non-specific ST - T wave changes .
# Labels: O O O O O O O O
#
# Sentence ID: 480
# Sentence: No previous tracing available for comparison .
# Labels: O O O O O O O
#
# ==================================================
# Total unique hadm_id count: 2

# %%
import pandas as pd

# Function to create a DataFrame from the extracted sentence information
def create_dataframe(extracted_texts):
    data = []

    for note_info in extracted_texts:
        if 'sentence_info' in note_info:
            hadm_id = note_info['hadm_id']
            note_id = note_info['note_id']
            for sentence_info in note_info['sentence_info']:
                words = sentence_info['words']
                labels = sentence_info['labels']
                sentence_id = sentence_info['sentence_id']

                for word, label in zip(words, labels):
                    data.append({
                        'hadm_id': hadm_id,
                        'note_id': note_id,
                        'sentence_id': sentence_id,
                        'word': word,
                        'label': label
                    })

    df = pd.DataFrame(data)
    return df

df = create_dataframe(extracted_texts)
print(df)
# Out:
#       hadm_id  note_id  sentence_id          word label
# 0      100197    25762            0     Admission     O
# 1      100197    25762            0          Date     O
# 2      100197    25762            0             :     O
# 3      100197    25762            0             [     O
# 4      100197    25762            0  **2136-10-23     O
# ...       ...      ...          ...           ...   ...
# 9868   101525   240524          480       tracing     O
# 9869   101525   240524          480     available     O
# 9870   101525   240524          480           for     O
# 9871   101525   240524          480    comparison     O
# 9872   101525   240524          480             .     O
#
# [9873 rows x 5 columns]

# %%
label_counts = df['label'].value_counts()
print(label_counts)
# Out:
# label
# O    9647
# I     140
# B      86
# Name: count, dtype: int64

# %%
token_df= df.drop(['hadm_id', 'note_id',], axis=1)

# %%
token_df
# Out:
#       sentence_id          word label
# 0               0     Admission     O
# 1               0          Date     O
# 2               0             :     O
# 3               0             [     O
# 4               0  **2136-10-23     O
# ...           ...           ...   ...
# 9868          480       tracing     O
# 9869          480     available     O
# 9870          480           for     O
# 9871          480    comparison     O
# 9872          480             .     O
#
# [9873 rows x 3 columns]

# %%
token_df.rename(columns = {'word':'words', 'label':'labels'}, inplace = True)

# %%
token_df.head()
# Out:
#    sentence_id         words labels
# 0            0     Admission      O
# 1            0          Date      O
# 2            0             :      O
# 3            0             [      O
# 4            0  **2136-10-23      O

# %%
token_df.to_csv('test_tokens.csv', index=False)

# %%
import pandas as pd

token_df= pd.read_csv('test_tokens.csv')

# %%
token_df.count()
# Out:
# sentence_id    9873
# words          9852
# labels         9873
# dtype: int64

# %%
#checking for null values
token_df.isnull().sum()
# Out:
# sentence_id     0
# words          21
# labels          0
# dtype: int64

# %%
data = token_df.fillna(method='ffill')
data.head()
# Out:
# C:\Users\okechukwu chude\AppData\Local\Temp\ipykernel_18076\3831777956.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = token_df.fillna(method='ffill')
#    sentence_id         words labels
# 0            0     Admission      O
# 1            0          Date      O
# 2            0             :      O
# 3            0             [      O
# 4            0  **2136-10-23      O

# %%
# let's create a new column called "sentence" which groups the words by sentence
data['sentence'] = data[['sentence_id','words','labels']].groupby(['sentence_id'])['words'].transform(lambda x: ' '.join(x))
# let's also create a new column called "word_labels" which groups the tags by sentence
data['word_labels'] = data[['sentence_id','words','labels']].groupby(['sentence_id'])['labels'].transform(lambda x: ','.join(x))
data.head()
# Out:
#    sentence_id         words labels  \
# 0            0     Admission      O
# 1            0          Date      O
# 2            0             :      O
# 3            0             [      O
# 4            0  **2136-10-23      O
#
#                                             sentence              word_labels
# 0  Admission Date : [ **2136-10-23 **] Discharge ...  O,O,O,O,O,O,O,O,O,O,O,O
# 1  Admission Date : [ **2136-10-23 **] Discharge ...  O,O,O,O,O,O,O,O,O,O,O,O
# 2  Admission Date : [ **2136-10-23 **] Discharge ...  O,O,O,O,O,O,O,O,O,O,O,O
# 3  Admission Date : [ **2136-10-23 **] Discharge ...  O,O,O,O,O,O,O,O,O,O,O,O
# 4  Admission Date : [ **2136-10-23 **] Discharge ...  O,O,O,O,O,O,O,O,O,O,O,O

# %%
label2id = {k: v for v, k in enumerate(data.labels.unique())}
id2label = {v: k for v, k in enumerate(data.labels.unique())}
label2id
# Out:
# {'O': 0, 'B': 1, 'I': 2}

# %%
data = data[["sentence", "word_labels"]].drop_duplicates().reset_index(drop=True)
data.head()
# Out:
#                                             sentence  \
# 0  Admission Date : [ **2136-10-23 **] Discharge ...
# 1         Date of Birth : [ ** 2056-7-14 **] Sex : M
# 2                             Service : NEUROSURGERY
# 3  Allergies : No Known Allergies / Adverse Drug ...
# 4  Attending :[** First Name3 ( LF ) 1835 **] Chi...
#
#                    word_labels
# 0      O,O,O,O,O,O,O,O,O,O,O,O
# 1        O,O,O,O,O,O,O,O,O,O,O
# 2                        O,O,O
# 3            O,O,O,O,O,O,O,O,O
# 4  O,O,O,O,O,O,O,O,O,O,O,O,O,O

# %%
data.head(7)
# Out:
#                                             sentence  \
# 0  Admission Date : [ **2136-10-23 **] Discharge ...
# 1         Date of Birth : [ ** 2056-7-14 **] Sex : M
# 2                             Service : NEUROSURGERY
# 3  Allergies : No Known Allergies / Adverse Drug ...
# 4  Attending :[** First Name3 ( LF ) 1835 **] Chi...
# 5           Major Surgical or Invasive Procedure : :
# 6  History of Present Illness : 80M p/w a large R...
#
#                                  word_labels
# 0                    O,O,O,O,O,O,O,O,O,O,O,O
# 1                      O,O,O,O,O,O,O,O,O,O,O
# 2                                      O,O,O
# 3                          O,O,O,O,O,O,O,O,O
# 4                O,O,O,O,O,O,O,O,O,O,O,O,O,O
# 5                              O,O,O,O,O,O,O
# 6  O,O,O,O,O,O,O,O,O,O,B,O,B,I,O,O,O,O,O,B,O

# %%
len(data)
# Out:
# 358

# %%
data.iloc[6].sentence
# Out:
# 'History of Present Illness : 80M p/w a large R IPH with intraventricular extension , midline shift , and hydrocephalus .'

# %%
data.iloc[6].word_labels
# Out:
# 'O,O,O,O,O,O,O,O,O,O,B,O,B,I,O,O,O,O,O,B,O'

# %%
filtered_df = data[~data['word_labels'].apply(lambda x: all(label == 'O' for label in x.split(',')))]

# %%
filtered_df.head()
# Out:
#                                              sentence  \
# 6   History of Present Illness : 80M p/w a large R...
# 11  He was taken to [ ** Hospital1 18 ** ] [ ** Lo...
# 15             He also had signed a DNR / DNI order .
# 20  History : - DIABETES TYPE II - HYPERLIPIDEMIA ...
# 37  [ ** Name2 ( NI ) ** ] was extubated on [ * * ...
#
#                                           word_labels
# 6           O,O,O,O,O,O,O,O,O,O,B,O,B,I,O,O,O,O,O,B,O
# 11  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 15                                O,O,O,O,O,B,O,O,O,O
# 20  O,O,O,B,I,I,O,B,O,B,O,B,O,B,I,I,I,I,I,I,I,I,O,...
# 37  O,O,O,O,O,O,O,O,O,B,O,O,O,O,O,O,O,O,O,O,O,O,O,...

# %%
filtered_df.iloc[1].sentence
# Out:
# 'He was taken to [ ** Hospital1 18 ** ] [ ** Location ( un ) 620 ** ] and head CT was performed , revealing a large intraparenchymal hemorrhage extending from the lower midbrain into the hypothalamus , thalamus and basal ganglia on the right , with significant mass effect , intraventricular extension with casting of the right ventricle and some blood product in the posterior [ ** Doctor Last Name 534 ** ] of the left lateral ventricle .'

# %%
filtered_df.iloc[1].word_labels
# Out:
# 'O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,B,I,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O'
